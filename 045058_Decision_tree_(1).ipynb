# %% [markdown]
# Fashion Segmentation
#
# Objective
#
# DESCRIPTION OF DATASET
#
# Description of Data
#
# 2.1. Data Source, Size, Shape
#
# 2.2 Description of Variables
#
# 2.3. Descriptive Statistics
#
# 2.3.1. Descriptive Statistics: Categorical Variables or Features
#
# 2.3.1.1. Count | Frequency Statistics
#
# 2.3.1.2. Proportion (Relative Frequency) Statistics
#
# 2.3.2. Descriptive Statistics: Non-Categorical Variables or Features
#
# 2.3.2.1. Measures of Central Tendency
#
# 2.3.2.2. Measures of Dispersion
#
# 2.3.2.3. Correlation Statistics (with Test of Correlation)
#
# Additional Information
#
# ANALYSIS OF DATA
#
# 3.1. Data Pre-Processing
#
# 3.1.1. Missing Data Statistics and Treatment
#
# 3.1.1.1. Missing Data Statistics: Records
#
# 3.1.1.2. Missing Data Treatment: Records
#
# 3.1.1.2. Missing Data Statistics: Categorical Variables or Features
#
# 3.1.1.2. Missing Data Treatment: Categorical Variables or Features
#
# 3.1.1.3. Missing Data Statistics: Non-Categorical Variables or Features
#
# 3.1.1.3. Missing Data Treatment: Non-Categorical Variables or Features
#
# 3.1.2. Numerical Encoding of Categorical Variables or Features
#
# 3.1.3. Outlier Statistics and Treatment
#
# 3.1.4. Data Transformation and Scaling
#
# 3.1.5. Pre-Processed Dataset
#
# Note:
#
# 3.2 Data Analysis
#
# Result / Managerial Implications
#
#
# Fashion Segmentation through decision tree , knn, logistic regression and  svm
# Objective:
# Enhancing Product Segmentation:
#
# 1.improve the granularity with which fashion products are segmented, which can help in more targeted marketing and inventory management.
# Models Used: Decision Trees and SVM are particularly good for handling categorical and continuous data in classification tasks.
# Optimizing Product Offerings:
#
# 2. Use insights from model predictions to tailor product offerings more closely to customer preferences and market demand.
# Models Used: Logistic Regression and KNN can help understand customer segments and predict customer preferences based on past data.
# Predicting and Classifying Product Categories:
#
# 3. Accurately classify products into predefined categories based on their features to streamline product sorting, searching, and recommendation processes.
# Models Used: SVM and Decision Trees provide robust classification mechanisms, which are crucial for accurate and efficient product categorization.
# Identifying Key Drivers of Product Preferences:
#
# 4. Determine which attributes of products (e.g., price, brand, type) most significantly affect consumer choices, enabling more effective product design and marketing strategies.
# Models Used: Logistic Regression and Decision Trees can elucidate relationships between product features and consumer choices, highlighting influential factors.
# Enhancing Decision-Making Processes:
#
# 5. Enhance the analytical capabilities of fashion retailers by providing them with detailed analysis and predictive insights that support strategic business decisions.
# Models Used: All chosen models can contribute to a deeper understanding of data patterns and customer behavior predictions.
#
# DESCRIPTION OF DATASET
# product_id: A unique identifier for each product
# brand_name: The name of the brand that makes the product
# title: The name of the product
# current_price: The current price of the product in USD
# previous_price: The previous price of the product in USD (if available)
# Gender: The gender that the product is targeted towards (M for Men)
# currency: The currency that the price is listed in (USD)
# rrp: The recommended retail price of the product (possibly in USD)
# productCode: A unique code for the product
# productType: The type of product (e.g. Product, Trainer)
#
#  2. **Description of Data**
#
# ##2.1. Data Source, Size, Shape
#
# 	### 2.1.1. Data Source (https://www.kaggle.com/datasets/imrulhasanrobi/e-commerce-big-dataset-from-multi-category)
#
# 	### 2.1.2. Data Size (2.85 MB)
#
# 	### 2.1.3. Data Shape (Dimension: Number of Variables-10 | Number of Records-61201 rows × 10 columns)
#
#
# ## 2.2 **Description of Variables**
#
# 1. Index Variable(s)
# - **Description**: Index variables serve as unique identifiers for each observation in the dataset. They are crucial for referencing and managing data but may not directly contribute to analysis.
#  product_id
#
# 2. Categorical Variables with Nominal Categories
# - **Description**: These variables represent categories without any inherent order or ranking. They are typically labels or groupings.
#   - **Brand Name**: Represents the manufacturer or brand of the product.
#   - **Gender**: Indicates the target gender for which the product is intended.
#   - **Currency**: Denotes the currency used for pricing.
#   - **Product Type**: Specifies the category or type of the product.
#
# 3. Non-Categorical Variables
# - **Description**: Non-categorical variables are numeric or continuous and do not fall into categorical or ordinal categories.
#   - **Current Price**: The current price of the product.
#   - **Previous Price**: The previous price of the product.
#   - **Recommended Retail Price (RRP)**: The manufacturer's suggested retail price for the product.
#
#
#
#
# ### 2.3. Descriptive Statistics
#
# #### 2.3.1. Descriptive Statistics: Categorical Variables or Features
#
# ##### 2.3.1.1. Count | Frequency Statistics
# - **product_id**: 61200 non-null entries
# - **brand_name**: 61200 non-null entries
# - **title**: 61200 non-null entries
# - **Gender**: 61200 non-null entries
# - **currency**: 61200 non-null entries
# - **productType**: 61200 non-null entries
#
# ##### 2.3.1.2. Proportion (Relative Frequency) Statistics
# - No proportions provided as these are nominal categorical variables.
#
# #### 2.3.2. Descriptive Statistics: Non-Categorical Variables or Features
#
# ##### 2.3.2.1. Measures of Central Tendency
# - **current_price**:
#   - Mean: 50.639433
#   - Median (50th percentile): 41.690000
# - **previous_price**:
#   - Mean: 51.095332
#   - Median (50th percentile): 44.210000
# - **rrp**:
#   - Mean: 94.259919
#   - Median (50th percentile): 78.000000
#
# ##### 2.3.2.2. Measures of Dispersion
# - **current_price**:
#   - Standard Deviation: 42.409025
#   - Min: 2.610000
#   - Max: 237.000000
# - **previous_price**:
#   - Standard Deviation: 35.690232
#   - Min: 6.320000
#   - Max: 165.810000
# - **rrp**:
#   - Standard Deviation: 68.221765
#   - Min: 8.690000
#   - Max: 372.000000
#
# ##### 2.3.2.3. Correlation Statistics (with Test of Correlation)
# - Correlation between variables not provided in this report.
#
# #### Additional Information
# - **Memory Usage**: 4.7+ MB
# - **Non-null Counts**:
#   - product_id: 61200
#   - brand_name: 61200
#   - title: 61200
#   - current_price: 61200
#   - previous_price: 25280
#   - Gender: 61200
#   - currency: 61200
#   - rrp: 43326
#   - productCode: 61200
#   - productType: 61200
#
#
#
# 3.1. Data Pre-Processing
# 3.1.1. Missing Data Statistics and Treatment
#
# 3.1.1.1. Missing Data Statistics: Records
# To start, you'll need a clear understanding of where the missing values occur in your dataset. Here’s a summary based on the information you provided:
#
#  -previous_price: 25,280 non-null entries out of 61,200 (35,920 missing values, approximately 58.7% missing)
#
#  -rrp (Recommended Retail Price): 43,326 non-null entries out of 61,200 (17,874 missing values, approximately 29.2% missing)
#
# Given the significant amount of missing data, especially in previous_price, the choice of treatment will significantly affect the dataset's structure and the accuracy of your models. Here are the detailed missing data statistics for the top 5 records with the most missing values:
#
# The records identified by their index numbers (1854, 198, 12942, 3078, 5814) each have 2 missing values. These missing values are likely in the previous_price and rrp columns based on overall missing data counts.
# #### 3.1.1.2. Missing Data Treatment: Records
#
# Mean/Median Imputation: Suitable for continuous variables with a normal distribution or when the missing data proportion is low. For current_price and rrp, median imputation might be more resistant to outliers.
# K-Nearest Neighbors (KNN) Imputation: Useful for datasets where the missing values can reasonably be approximated by considering the similarity of other records.
# Deletion:
#
# Listwise Deletion: If a record has missing values, it’s removed from analysis. This method is simple but can lead to bias if the missing data is not completely random.
# Pairwise Deletion: Used in statistical analyses to use all available data by analyzing pairs of variables that have valid data, but it’s not typically used in modeling contexts like K-Means.
# Using a Constant to Fill in Missing Values: Sometimes used for categorical data or to indicate missingness if it’s informative.
#
# Prediction Models: Regression models, decision trees, or machine learning models can predict missing values based on other variables in the dataset.
#
# Multiple Imputation: A more sophisticated approach that involves creating multiple different plausible imputations and combining the results to address the uncertainty caused by the missing data.
#
# #3.1.1.2. Missing Data Statistics: Categorical Variables or Features
# Given that there are no missing values among the categorical variables, no direct imputation or removal procedures are required for these fields. This is advantageous because categorical data can often complicate missing data treatment due to the need for mode imputation or the use of more complex imputation methods like predictive modeling or using dummy variables to represent missing categories.
#
# Summary of Categorical Variables:
# product_id: 61,200 non-null entries
# brand_name: 61,200 non-null entries
# title: 61,200 non-null entries
# Gender: 61,200 non-null entries
# currency: 61,200 non-null entries
# productType: 61,200 non-null entries
#
# #3.1.1.2. Missing Data Treatment: Categorical Variables or Features
# However, while there's no immediate need for missing data treatment in your categorical variables due to their completeness, it's important to have a strategy in place should this issue arise in future data or in a scenario where data might not be fully complete.
#
# #3.1.1.3. Missing Data Statistics: Non-Categorical Variables or Features
#
# 3.1.1.3. Missing Data Statistics: Non-Categorical Variables or Features
# From the dataset information you provided, here’s a summary of the missing data for non-categorical (numeric) variables:
#
# previous_price: 25,280 non-null entries out of 61,200 total entries, which means there are 35,920 missing entries (approximately 58.7% missing).
# rrp (Recommended Retail Price): 43,326 non-null entries out of 61,200 total entries, which indicates 17,874 missing entries (approximately 29.2% missing).
# These two variables show a significant amount of missing data, particularly previous_price. The high percentage of missing values in previous_price can be a major concern as it might influence the reliability and validity of any statistical analysis or modeling, including clustering.
#
# Analysis of Non-Categorical Missing Data
# The high proportion of missing data, especially in previous_price, suggests that a careful approach is required. It’s important to consider why this data might be missing. For example:
#
# Are there systematic reasons why rrp might be missing, such as certain brands or product types not providing a suggested retail price?
# Understanding the reasons behind the missing data can guide the choice of treatment methods, such as whether to impute, delete, or otherwise handle these missing entries.
#
#
# #3.1.1.3. Missing Data Treatment: Non-Categorical Variables or Features
# Given your dataset where the previous_price has a significant amount of missing data (about 58.7%), your approach to missing data treatment for non-categorical variables involves thoughtful consideration. The strategies you outlined are sensible and typically effective for handling such situations in data science projects. Here's an expanded discussion on each method:
#
# 1. Removal of Variables or Features with More Than 50% Missing Data
# Although previous_price exceeds the 50% missing data threshold you've set, you've opted not to remove this variable. This decision might be driven by the importance of previous_price in your analysis, such as its potential impact on understanding pricing strategies or changes over time. When a variable is crucial for analysis or expected outcomes, retaining and appropriately treating the missing data can be more beneficial than removing it.
#
# 2. Imputation of Missing Data using Descriptive Statistics
# For the variables previous_price and rrp, where missing data is significant but not to be removed, imputation using mean or median can help maintain the dataset’s integrity without introducing excessive bias:
#
# Mean Imputation: Best used when the data distribution is symmetric and there are no extreme outliers. Mean imputation can be skewed by outliers, which might distort the data representation.
#
# Median Imputation: More robust against outliers and skewed data. It is typically preferred when the data distribution is not symmetric or when outliers are present.
#
# ### 3.1.2. Numerical Encoding of Categorical Variables or Features
#
# 1. `df_cat = df[['Gender', 'productType','brand_name']]`: This line creates a new DataFrame `df_cat` containing only the columns 'Gender', 'productType', and 'brand_name' from the original DataFrame `df`. These columns are typically considered categorical because they represent categories or labels rather than numerical data. Categorical data can further be divided into nominal (categories without an inherent order) or ordinal (categories with a specific order).
#
# 2. `df_noncat = df[['current_price', 'rrp','previous_price']]`: Similarly, this line creates a new DataFrame `df_noncat` containing only the columns 'current_price', 'rrp', and 'previous_price'. These columns are numerical data representing prices, and thus are considered non-categorical.
#
#
# The comments `# Categorical Data [Nominal | Ordinal]` and `# Non-Categorical Data` provide a brief description of the type of data contained in each DataFrame. The comment suggests that the 'Gender', 'productType', and 'brand_name' columns may contain either nominal or ordinal categorical data, while the 'current_price', 'rrp', and 'previous_price' columns contain non-categorical data (i.e., numerical data).
#
# Overall, this code is simply splitting the original DataFrame into two separate DataFrames based on the type of data they contain, which can be useful for subsequent analysis or preprocessing tasks specific to each data type.
#
# ### 3.1.3. Outlier Statistics and Treatment
#
# Outlier Detection:
#
# - Identified outliers using boxplot visualization for numeric variables.
#
# Outlier Treatment:
#
# - Outliers treated by performing normalization using Min-Max Scaler.
#
# ### 3.1.4. Data Transformation and Scaling
#
# - **Normalization**: Min-Max Scaling applied to non-categorical variables to bring them within a common scale.
#
# ### 3.1.5. Pre-Processed Dataset
#
# - **Pre-Processed Categorical Data Subset**: Encoded categorical data using Ordinal Encoder.
# - **Pre-Processed Non-Categorical Data Subset**: Normalized non-categorical data using Min-Max Scaler.
# - **Pre-Processed Dataset**: Merged pre-processed categorical andnon-categorical data subsets.
#
# ### Note:
#
# - No data bifurcation into training and testing sets was required as part of this analysis.

# %% [markdown]
# ##*3.2. Data Analysis*
#
#  *3.2.1.1. PO1 | PS1:: Supervised Machine Learning Classification Algorithm:  Decision Tree (Base Model)
# Decision Tree Overview
# A Decision Tree is a non-parametric supervised learning method used for both classification and regression tasks. The goal is to create a model that predicts the value of a target variable by learning simple decision rules inferred from the data features. For classification tasks like yours, Decision Trees can be especially powerful and interpretable.
#
# Metrics Used:
# Gini Coefficient: A measure of a node's impurity. A Gini score of 0 represents perfect purity, with all samples in a node belonging to a single class. The Gini coefficient for this model is 0.537, which suggests that while there is some impurity, the model does a reasonable job of classifying the data.
# Entropy: Used as a split criterion that measures the level of uncertainty or impurity in a group of examples. The value of 0.60 for entropy indicates that the dataset within the nodes after the splits retains a moderate level of disorder or mixed classes, but it is relatively low, suggesting effective class separation.
#
# Analysis:
# The Decision Tree base model, utilizing the Gini Coefficient and Entropy as metrics, shows competent performance:
#
# Gini Coefficient (0.537): This value is moderate and implies that the model has decent discriminatory power. It is not perfect, which means there is room for improvement, possibly by tuning hyperparameters like max depth or min samples split, or by using more sophisticated tree-based models like Random Forests or Gradient Boosting Machines.
# Entropy (0.60): Similarly, this entropy level indicates that the model does a good job of reducing uncertainty with each decision it makes, albeit not completely. The branches of the tree are likely finding relevant thresholds that meaningfully divide the classes.
#
#
# For the comparison models, the obtained metrics are:
#
# *Logistic Regression:*
# - Gini Coefficient: 0.72
# - Entropy: 0.58
#
# *Support Vector Machine:*
# - Gini Coefficient: 0.78
# - Entropy: 0.61
#
# *K Nearest Neighbour:*
# - Gini Coefficient: 0.70
# - Entropy: 0.56
#
# *Analysis:* Comparing the Decision Tree base model's metrics with other classification algorithms, we observe that the Support Vector Machine achieves the highest Gini coefficient (0.78), indicating superior discriminatory power among the models considered. However, the Decision Tree still performs reasonably well, with a Gini coefficient of 0.75.
#
# PO2 | PS2: Classification Model Performance Evaluation
# Base Model: Decision Tree
# Model Overview:
# Your Decision Tree model has been constructed with the following splits based on Gender_code, current_price_mmnorm, and currency_code. The feature importances indicate that Gender_code is the most significant predictor, followed by current_price_mmnorm and currency_code, while productType_code, rrp_mmnorm, and previous_price_mmnorm do not contribute to the model.
#
# Model Performance Metrics:
#
# Accuracy: 100% for both training and testing datasets.
# Precision, Recall, F1-Score: Perfect scores across all classes (0, 1, 2, 3).
# Model Performance Evaluation:
#
# Accuracy: The model achieves perfect accuracy, which indicates that every prediction made by the model matches the actual class labels. This is an excellent performance metric but might raise concerns about overfitting, especially if such results are not consistent across unseen data.
# Precision: Measures the accuracy of positive predictions. A score of 1.00 across all classes suggests that every instance predicted by the model as belonging to a certain class was indeed of that class.
# Recall: Measures the ability of the model to find all the relevant cases within a dataset. The score of 1.00 indicates the model successfully identified all instances of each class.
# F1-Score: The harmonic mean of precision and recall. A score of 1.00 suggests a perfect balance between precision and recall — an ideal scenario in classification tasks.
# Detailed Evaluation:
#
# Decision Rules Overview:
#
# For products likely targeted towards females or unisex (Gender_code <= 0.50):
# If the normalized current price is less than or equal to 0.46:
# If the currency code is 1.50 or less, it classifies as class: 2.
# If the currency code is greater than 1.50, it classifies as class: 1.
# If the normalized current price is greater than 0.46, it classifies as class: 3.
# For products likely targeted towards males (Gender_code > 0.50):
# If the normalized current price is less than or equal to 0.71, it classifies as class: 0.
# If the normalized current price is greater than 0.71, it classifies as class: 3.
#
#
#
# *3.2.2.1.2. PO2 | PS2:: Classification Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Base Model: Decision Tree)*
#
# For the Decision Tree model, time statistics and memory usage values are:
#
# Comparison Models: Logistic Regression | Support Vector Machine | K Nearest Neighbour
# Logistic Regression:
# Accuracy: 1.0
# Precision: 1.00 for all classes
# Recall: 1.00 for all classes
# F1-Score: 1.00 for all classes
# Support Vector Machine (SVM):
# Accuracy: 1.0
# Precision: 1.00 for all classes
# Recall: 1.00 for all classes
# F1-Score: 1.00 for all classes
# K-Nearest Neighbors (KNN):
# Accuracy: 1.0 for all k values tested
# Precision: 1.00 for all classes
# Recall: 1.00 for all classes
# F1-Score: 1.00 for all classes
# Confusion Matrix for Each Model:
# All models showed a confusion matrix with no misclassified instances. Every class label was predicted with 100% accuracy.
# Evaluation Summary:
# All three models achieved perfect scores across all evaluation metrics. This is highly unusual in real-world settings and might indicate that the models are overfitting, the dataset lacks variability, or the test set is not sufficiently challenging.
#
# *3.2.2.2.2. PO2 | PS2:: Classification Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Comparison Models: Logistic Regression | Support Vector Machine | K Nearest Neighbour)*
# Let's summarize and compare the performance of the Logistic Regression, Support Vector Machine (SVM), and K-Nearest Neighbors (KNN) models based on the data you have provided:
#
# Classification Model Performance Evaluation
# Logistic Regression:
# Training Time: 0.470 seconds
# Prediction Time: 0.0043 seconds
# Accuracy: 1.0
# Memory Usage: 325.71 MB
# Support Vector Machine (SVM):
# Training Time: 2.004 seconds
# Prediction Time: 1.519 seconds
# Accuracy: 1.0
# Memory Usage: 327.20 MB
# K-Nearest Neighbors (KNN) - (With various k values):
# Training Time: Ranged approximately from 0.11 to 0.16 seconds
# Accuracy: Consistently 1.0 for all k-values
# Memory Usage: Peaked around 332.93 MB
# All three models achieved an accuracy of 1.0, indicating perfect classification on the given dataset. However, there are notable differences in their computational performance:
#
# Training Time: SVM took the longest time to train, followed by Logistic Regression, while KNN generally had the shortest training time among the three.
# Prediction Time: SVM also took the most time to make predictions, which is characteristic of the model, especially when using kernel methods that require computing distances between support vectors and the entire dataset.
# Memory Usage: Memory usage was fairly consistent across the models, with KNN showing a slightly higher memory consumption, which is typical given that KNN stores the entire dataset for prediction.
#
# *3.2.3.1. PO3 | PS3:: Variable or Feature Analysis: Base Model (Decision Tree)*
# For PO3 | PS3, we’ll dive into the feature analysis for the Decision Tree model, which is the base model you've described. This analysis is crucial to understand the importance of different variables in making predictions and how they impact the model's decisions.
#
# Variable or Feature Analysis: Base Model (Decision Tree)
# Key Features:
# Gender_code (Importance: 0.657)
#
# Interpretation: This variable has the highest feature importance. It indicates a strong relationship between the product's targeted gender and the product classification.
# Impact: The decision tree first splits on this feature, suggesting that gender plays a significant role in the classification process, possibly reflecting differences in product preferences or offerings across genders.
# Current_price_mmnorm (Importance: 0.238)
#
# Interpretation: The normalized current price is the second most important feature. It affects the classification, particularly after the initial split on Gender_code, reflecting the price's influence on the product categorization.
# Impact: Price is often a primary consideration for consumers, and this variable's importance signifies that pricing strategy could be key in product placement and marketing.
# Currency_code (Importance: 0.106)
#
# Interpretation: Currency code has a lower importance than gender and price but still plays a role in further splits, suggesting some regional effects on the classification.
# Impact: Currency could be a proxy for geographical market variations, indicating that regional pricing and economic factors may influence how products are classified.
# Other Variables (Importance: 0.000)
#
# Interpretation: Features such as productType_code, rrp_mmnorm, and previous_price_mmnorm have zero importance in the model constructed.
# Impact: These variables do not contribute to the decision-making process in the current model. This may indicate redundancy, lack of variability, or irrelevance to the classification objectives.
#
# *3.2.3.2. PO3 | PS3:: Variable or Feature Analysis: Comparison Models (Logistic Regression | Support Vector Machine | K Nearest Neighbour)*
#
#
# Logistic Regression:
#
# Gender_code: 1.0
# Current_price_mmnorm: 1.0
# Currency_code: 1.0
# ProductType_code: 1.0
# RRP_mmnorm: 1.0
# Previous_price_mmnorm: 1.0
# Support Vector Machine (SVM):
#
# Gender_code: 1.0
# Current_price_mmnorm: 1.0
# Currency_code: 1.0
# ProductType_code: 1.0
# RRP_mmnorm: 1.0
# Previous_price_mmnorm: 1.0
# K Nearest Neighbour (KNN):
#
# Gender_code: 1.0
# Current_price_mmnorm: 1.0
# Currency_code: 1.0
# ProductType_code: 1.0
# RRP_mmnorm: 1.0
# Previous_price_mmnorm: 1.0
# All features have the same importance score of 1.0 across all models, indicating that each feature is equally significant in predicting the target variable.
#
# From the analysis, it appears that all the features have equal importance across all three models: Logistic Regression, Support Vector Machine (SVM), and K Nearest Neighbour (KNN). This suggests that each feature contributes equally to the predictive power of the models.
#
# Such uniform feature importance scores may indicate either of the following scenarios:
#
# Highly correlated features: The features might be highly correlated with each other, making it difficult for the models to differentiate their individual importance. In such cases, feature engineering or dimensionality reduction techniques may be beneficial to improve model performance.
#
# Artificial data: The features could be generated artificially or engineered in such a way that they have equal importance. This might occur if the data is synthetic or manipulated for experimental purposes.
#
# ##*4. Results | Observations*
#
# *4.1. Classification Model Parameters: Base Model (Decision Tree) | Comparison Models (Logistic Regression | Support Vector Machine | K Nearest Neighbour)*
#
# Decision Tree (Base Model):
#
# The Decision Tree model achieved perfect classification accuracy (1.0) on the test data.
# It was the fastest in terms of training time (0.028664 seconds), indicating high efficiency.
# The memory usage was moderately low at approximately 328.31 MB.
# The feature 'Gender_code' was found to be the most significant in making splits, followed by 'current_price_mmnorm' and 'currency_code', suggesting these features have a high predictive power.
# Logistic Regression:
#
# Logistic Regression also scored a perfect accuracy of 1.0.
# It required a relatively moderate training time (0.367873 seconds) and used approximately 327.90 MB of memory, which is slightly less than the Decision Tree model.
# Given the nature of Logistic Regression, the model’s coefficients can be examined to understand the effect of each feature on the outcome, although specific details were not included in the provided data.
# Support Vector Machine (SVM):
#
# SVM achieved the same high accuracy as the other models.
# However, it took considerably longer for both training (2.004162 seconds) and prediction (1.518824 seconds) compared to the Decision Tree and Logistic Regression models.
# Memory usage was 327.20 MB, comparable to Logistic Regression but slightly less than some of the KNN models.
# K Nearest Neighbour (KNN):
#
# KNN maintained a consistent accuracy of 1.0 across different values of k (5 to 17).
# The training times ranged from 0.105738 seconds to 0.156024 seconds, depending on the value of k, with memory usage also slightly increasing with k.
# KNN models were generally quick and efficient but offered no direct interpretation of feature importance.
# Observations:
#
# All models demonstrated a perfect accuracy of 1.0, which is highly unusual in practice and may suggest overfitting, especially since there are no errors reported in the confusion matrices.
# The Decision Tree was the most efficient model in terms of computational time and resources.
# Logistic Regression offered a good balance between efficiency and potential interpretability.
# SVM showed a high computational cost, which may not be justified given the comparable performance of the less resource-intensive models.
# Despite the lack of feature importance in KNN, its performance was consistent across all k values tested.
#
# *4.2. Classification Model Performance: Time & Memory Statistics [Base Model (Decision Tree) | Comparison Models (Logistic Regression | Support Vector Machine | K Nearest Neighbour)]*
#
# Decision Tree (Base Model):
#
# Time Taken for Training: 0.028664 seconds, demonstrating high speed and efficiency.
# Memory Used: 328.308594 MB, which is reasonable given the complexity of the model.
# Logistic Regression:
#
# Time Taken for Training: 0.367873 seconds, which is longer than the Decision Tree but still within an acceptable range for training.
# Memory Used: 327.902344 MB, slightly less than the Decision Tree, making it efficient in terms of space complexity.
# Support Vector Machine (SVM):
#
# Time Taken for Training: 1.743976 seconds, which is significantly higher than both the Decision Tree and Logistic Regression, reflecting the computationally intensive nature of the SVM, especially for large datasets.
# Memory Used: 331.203125 MB, which is comparable to the other models but is the highest among the ones reported.
# K Nearest Neighbor (KNN):
#
# Time Taken for Training: Varied slightly with the value of k, ranging from 0.105738 seconds to 0.156024 seconds. This variation is due to the computation of distances to different numbers of neighbors.
# Memory Used: Increased with the value of k, from 330.652344 MB to 332.929688 MB. The increase is minimal but consistent as k increases.
#
#
# *4.3. Variable or Feature Analysis: Base Model (Decision Tree) | Comparison Models (Logistic Regression | Support Vector Machine | K Nearest Neighbour)*
#
#
# Base Model (Decision Tree) | Comparison Models (Logistic Regression | Support Vector Machine | K Nearest Neighbour)
# Decision Tree (Base Model):
#
# The Decision Tree model offers straightforward insights into feature importance. The 'Gender_code' feature was the most significant for splitting the data, followed by 'current_price_mmnorm' and 'currency_code'. This suggests that these features have a strong predictive power for the target variable in the dataset.
# The tree structure allows for an intuitive interpretation of feature interactions and their hierarchical importance in the decision-making process.
# Logistic Regression:
#
# Logistic Regression coefficients represent the log odds of the outcome and can be used to infer feature importance. Higher absolute coefficient values indicate a greater impact of the corresponding feature on the outcome variable.
# While specific coefficients are not detailed in the results provided, in general, Logistic Regression would allow for an understanding of the direction and strength of the relationship between each feature and the predicted probability.
# Support Vector Machine (SVM):
#
# Feature importance in SVMs, especially for non-linear kernels, is not as straightforward to interpret as in Decision Trees or Logistic Regression.
# For linear SVMs, the weights can be inspected to understand feature importance. However, in cases of non-linear SVMs, techniques such as examining the support vectors or using model-agnostic methods might be necessary to assess feature impact.
# K Nearest Neighbour (KNN):
#
# KNN does not provide a direct measure of feature importance as it relies on the distance between instances. All features contribute to the computation of similarity between instances, with the most important features being those that most effectively differentiate classes when calculating distances.
# Feature scaling and selection can significantly impact KNN's performance, highlighting the implicit importance of variables.
# Comparative Analysis:
#
# The Decision Tree provides the most transparent analysis of feature importance among the four models, with a clear hierarchy of features based on their splits.
# Logistic Regression and linear SVM can provide insights into feature importance through model coefficients, albeit the latter requires additional steps if using a non-linear kernel.
# KNN does not offer an inherent method for evaluating feature importance, emphasizing the model's dependency on feature scaling and the chosen distance metric
#
#
# *4.3.2. List of Non-Relevant or Non-Important Variables or Features*
# 4.3.2. List of Non-Relevant or Non-Important Variables or Features
# Overview
# This subsection identifies the variables that have shown minimal or no impact on the predictive performance of the models studied. Identifying such variables is crucial for streamlining the models, reducing complexity, and improving computational efficiency.
#
# Identified Non-Important Variables
# Decision Tree:
#
# From the decision tree analysis, it is clear that certain features like 'productType_code', 'rrp_mmnorm', and 'previous_price_mmnorm' did not play a role in the decision-making process. These features were not used for any splits in the tree, indicating their low predictive power or redundancy in the presence of other features.
# Logistic Regression:
#
# While specific coefficients were not provided, in general, features that would have very low or zero coefficients in a Logistic Regression model are considered to have negligible effects on the outcome. Assuming that such details are consistent with those of the Decision Tree, it can be inferred that features like 'productType_code' might also be less impactful in Logistic Regression.
# Support Vector Machine (SVM):
#
# SVM, particularly if using a non-linear kernel, might implicitly deem certain features less important based on the support vectors. However, without explicit feature elimination or reduction techniques, identifying these non-important features from SVM results directly can be challenging. It is likely that features showing non-importance in other models would similarly have minimal impact.
# K Nearest Neighbor (KNN):
#
# KNN inherently considers all features in its distance calculations unless feature weighting is applied. Therefore, all features are assumed relevant unless domain knowledge or additional feature selection techniques are employed to determine otherwise.
# Common Findings Across Models
# Based on the above analysis, 'productType_code', 'rrp_mmnorm', and 'previous_price_mmnorm' emerge as candidates for non-important features across the models where feature importance can be assessed.
# The lack of variability or low variance in these features across the dataset might be a reason for their limited impact on model performance, which could be confirmed through further statistical analysis or feature importance techniques such as permutation importance.
#
#
# In the section "5. Managerial Insights," you should aim to provide actionable advice and strategic guidance based on the results and analyses of the models. For subsection "5.1. Appropriate Model: Compare and Contrast {Decision Tree | Logistic Regression | Support Vector Machine | K Nearest Neighbour}," here's how you could structure and present your insights:
#
# #5. Managerial Insights
# 5.1. Appropriate Model: Compare and Contrast {Decision Tree | Logistic Regression | Support Vector Machine | K Nearest Neighbour}
# Decision Tree:
#
# Pros: Fast training and prediction times make it highly efficient. The model's interpretability is a significant advantage for decision-making, as it provides clear rules and criteria that led to each prediction. Minimal memory usage.
# Cons: Prone to overfitting, especially with perfect accuracy scores. Limited capability in handling non-linear relationships unless depth and complexity are increased.
# Best Use: Suitable for applications where interpretability is critical, and the decision process needs to be transparent, such as in credit scoring or medical diagnosis scenarios.
# Logistic Regression:
#
# Pros: Offers a good balance between efficiency and predictive power. Coefficients of the model provide insights into the importance of each feature, aiding in understanding how changes in predictors affect the outcome. Handles binary outcomes naturally.
# Cons: Assumes linearity between dependent and independent variables. Struggles with complex relationships that might be better captured by non-linear models.
# Best Use: Ideal for risk assessment and probability estimation, such as in customer churn prediction or disease likelihood modeling, where understanding the impact of features is crucial.
# Support Vector Machine (SVM):
#
# Pros: Excellent performance with high-dimensional data. Capable of modeling non-linear decision boundaries through the use of kernel functions.
# Cons: High computational cost in terms of training and prediction time, and memory usage. Less interpretable compared to Decision Tree and Logistic Regression.
# Best Use: Best for image classification, text categorization, and complex problems where the decision boundary is not linear, and high accuracy is paramount.
# K Nearest Neighbour (KNN):
#
# Pros: Simple and effective, with the model not assuming any underlying data distribution. Adaptable to any changes in the input data without requiring retraining.
# Cons: Computationally expensive as the dataset grows, impacting scalability. Performance heavily dependent on the choice of the distance metric and the value of k.
# Best Use: Useful in recommendation systems and classification tasks where the decision boundary is irregular, making model simplicity and flexibility valuable attributes.
# Comparative Insights:
#
# Efficiency: Decision Tree offers the best efficiency in terms of computational resources and time, followed by Logistic Regression. SVM is the least efficient but provides robustness in complex scenarios.
# Accuracy and Overfitting: All models demonstrated perfect accuracy, which may indicate overfitting. Logistic Regression and SVM, with their regularization capabilities, might better handle this in real-world applications.
# Interpretability: Decision Tree and Logistic Regression offer more straightforward insights into how decisions are made, which can be crucial for managerial decision-making and strategy planning.
#
# **5.2. Relevant or Important Variables or Features (Given the Appropriate Model)
# Overview**
# Understanding the impact of relevant or important features within chosen models can provide significant managerial insights, helping guide more informed decisions regarding resource allocation, strategy development, and operational adjustments.
#
# Decision Tree
# Key Variables: 'Gender_code', 'current_price_mmnorm', and 'currency_code'.
# Managerial Insight: These variables are pivotal in determining the outcomes of the model. For example, 'Gender_code' could be indicative of different purchasing behaviors between genders, influencing marketing strategies. Adjusting pricing strategies could also be guided by insights from 'current_price_mmnorm'.
# Logistic Regression
# Key Variables: Assuming the coefficients are significant, predictors like 'Gender_code' and 'current_price_mmnorm' may also be influential here.
# Managerial Insight: The coefficients provide a direct measure of how much each predictor affects the odds of the target outcome. Managers can use this information to tweak features that are found to heavily influence customer decisions, potentially optimizing outcomes such as customer retention or conversion rates.
# Support Vector Machine (SVM)
# Key Variables: While specific features are not typically highlighted in SVM, features that alter the position of the hyperplane significantly could be considered important.
# Managerial Insight: Understanding which features most strongly define the hyperplane can help in identifying critical factors that distinguish between classifications. This could be especially useful in quality control or fault detection scenarios.
# K Nearest Neighbour (KNN)
# Key Variables: Due to KNN’s reliance on the distance metric, all features may be considered relevant, but especially those that frequently differentiate nearest neighbors from the farthest ones.
# Managerial Insight: This model’s sensitivity to feature distances suggests that small changes in input features could significantly alter outcomes. Managers should focus on understanding which features contribute most to customer segmentation or localization services.
#
# #Real-Life Managerial Insights
# Introduction:
# The application of machine learning models provides a robust framework for making informed decisions across various sectors. The insights derived from these models can streamline operations, optimize marketing strategies, and improve customer experiences. Below, we explore practical implications of deploying these models within different business contexts.
#
# 1. Marketing and Sales Strategy Optimization
# Insight from Decision Tree: The prominence of the 'Gender_code' variable suggests that gender plays a crucial role in customer preferences and behaviors. This can be leveraged to tailor marketing campaigns that are gender-specific, potentially increasing engagement and conversion rates.
# Action: Develop segmented marketing strategies that cater to the distinct preferences identified through the model, optimizing advertising spend and content according to gender-based trends.
# 2. Dynamic Pricing Strategies
# Insight from Logistic Regression and Decision Tree: Variables like 'current_price_mmnorm' impact customer purchase decisions significantly. This highlights the sensitivity of sales volumes to pricing strategies.
# Action: Implement dynamic pricing models that adjust prices in real-time based on demand, inventory levels, and customer purchase history to maximize revenue and profitability.
# 3. Customer Relationship Management
# Insight from KNN: Since KNN depends on the similarity of instances, understanding which features define customer clusters can help in identifying customer needs and preferences more accurately.
# Action: Use cluster analysis to improve customer segmentation and personalize services and offers, enhancing customer satisfaction and loyalty.
# 4. Risk Management
# Insight from SVM: The ability of SVM to effectively handle complex and high-dimensional data makes it ideal for identifying subtle patterns in customer behavior that may indicate potential fraud or default.
# Action: Deploy SVM models to monitor transactions in real-time, flagging anomalies that could indicate fraudulent activity, thus reducing potential losses.
# 5. Operational Efficiency
# Insight from All Models: The consistent performance across models suggests that certain processes and features are well-understood and effectively managed.
# Action: Automate decision-making processes in areas like inventory management and quality control, where predictive models show high accuracy, freeing up resources to focus on more strategic tasks.
# 6. Product Development
# Insight from Feature Importance: Understanding which features significantly impact the model’s predictions can inform product development, focusing on attributes most valued by customers.
# Action: Integrate customer feedback and model insights to guide the development of new features or products that align with consumer demands and preferences, potentially increasing market share.
# Conclusion
# Machine learning models offer more than just predictions; they provide a deeper understanding of the factors driving business outcomes. By integrating these insights into day-to-day operations and strategic planning, organizations can enhance their agility, customer centricity, and competitive edge. The key is not only in choosing the right model but also in continuously refining these models and their inputs to adapt to changing market conditions and business needs.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df=pd.read_csv("proj_2.csv")
df
# Out:
#        Unnamed: 0  product_id         brand_name  \
# 0               0   204499665             Replay
# 1               1   203420859       Jack & Jones
# 2               2   204285229       Jack & Jones
# 3               3   202261918  Don't Think Twice
# 4               4   202191610  Another Influence
# ...           ...         ...                ...
# 61195       61195   203652134               Dune
# 61196       61196   203778655               Dune
# 61197       61197   203202947             NaaNaa
# 61198       61198   204060148         Brave Soul
# 61199       61199   204347411  French Connection
#
#                                                    title  current_price  \
# 0                                Replay t-shirt in white          72.00
# 1              Jack & Jones script logo t-shirt in white          17.00
# 2                   Jack & Jones logo polo in pale green          34.00
# 3                   DTT denim board shorts in light blue          31.00
# ...

# %%
df_cat = df[['Gender', 'currency','productType']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['current_price', 'rrp','previous_price']] # Non-Categorical Data

# %% [markdown]
# import pandas as pd
# import re
#
# def remove_special_characters(text):
#     # Define the pattern for special characters excluding '.'
#     pattern = r'[^a-zA-Z0-9\s\.]'
#     # Replace special characters with an empty string
#     return re.sub(pattern, '', str(text))
#
# # Apply the function to remove special characters from all columns
# for column in df.columns:
#     df[column] = df[column].apply(remove_special_characters)
#
# print(df)

# %%
print(df.info()) # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
print(variable_missing_data)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61200 entries, 0 to 61199
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      61200 non-null  int64
#  1   product_id      61200 non-null  int64
#  2   brand_name      61200 non-null  object
#  3   title           61200 non-null  object
#  4   current_price   61200 non-null  float64
#  5   previous_price  25280 non-null  float64
#  6   Gender          61200 non-null  object
#  7   currency        61200 non-null  object
#  8   rrp             43326 non-null  float64
#  9   productCode     61200 non-null  int64
#  10  productType     61200 non-null  object
#  11  cluster         61200 non-null  int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 5.6+ MB
# None
#          Unnamed: 0    product_id  current_price  previous_price  \
# count  61200.000000  6.120000e+04   61200.000000    25280.000000
# ...

# %%
# 1.2.1. Impute Missing Categorical Data [Nominal | Ordinal] using Descriptive Satatistics : Central Tendency (Mode)
# ------------------------------------------------------------------------------------------------------------------

# Dataset Used : df_cat

si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
print(df_cat_mdi)
df_cat_mdi.info()
# Out:
#       Gender currency      productType
# 0          M      USD          Product
# 1          M      USD          Product
# 2          M      USD          Product
# 3          M      USD          Product
# 4          M      USD          Product
# ...      ...      ...              ...
# 61195      F      USD          Product
# 61196      F      USD          Product
# 61197      F      USD          Product
# 61198      F      USD          Product
# 61199      F      USD  MixMatchProduct
#
# [61200 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61200 entries, 0 to 61199
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       61200 non-null  object
#  1   currency     61200 non-null  object
#  2   productType  61200 non-null  object
# dtypes: object(3)
# memory usage: 1.4+ MB

# %%
# Dataset Used : df_noncat

si_noncat = SimpleImputer(missing_values=np.nan, strategy='mean') # Other Strategy : mean | median | most_frequent | constant
si_noncat_fit = si_noncat.fit_transform(df_noncat)
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat.columns); df_noncat_mdi_si # Missing Non-Categorical Data Imputed Subset using Simple Imputer
df_noncat_mdi_si.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61200 entries, 0 to 61199
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   current_price   61200 non-null  float64
#  1   rrp             61200 non-null  float64
#  2   previous_price  61200 non-null  float64
# dtypes: float64(3)
# memory usage: 1.4 MB

# %%
#Numeric Encoding of Categorical Data [Nominal & Ordinal]
df_cat_mdt_code = df_cat.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdi)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['Gender_code', 'productType_code','currency_code']); df_cat_code_oe
df_cat_mdt_code_oe = df_cat_mdi.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
#df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True);
df_cat_mdt_code_oe
# Out:
#       Gender currency      productType  Gender_code  productType_code  \
# 0          M      USD          Product          1.0               0.0
# 1          M      USD          Product          1.0               0.0
# 2          M      USD          Product          1.0               0.0
# 3          M      USD          Product          1.0               0.0
# 4          M      USD          Product          1.0               0.0
# ...      ...      ...              ...          ...               ...
# 61195      F      USD          Product          0.0               0.0
# 61196      F      USD          Product          0.0               0.0
# 61197      F      USD          Product          0.0               0.0
# 61198      F      USD          Product          0.0               0.0
# 61199      F      USD  MixMatchProduct          0.0               0.0
#
#        currency_code
# 0                2.0
# 1                2.0
# 2                2.0
# 3                2.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and contains the columns 'Offers', 'Average Price', and 'Number of Ratings'
df_noncat = df[['current_price', 'rrp','previous_price']]

# Create vertical boxplot for 'Offers'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['current_price'])
plt.title('Boxplot of current_price')
plt.ylabel('current_price')
plt.show()

# Create vertical boxplot for 'Average Price'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['rrp'])
plt.title('Boxplot of rrp')
plt.ylabel('rrp')
plt.show()

# Create vertical boxplot for 'Average Price'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['previous_price'])
plt.title('Boxplot of previous_priceprevious_price')
plt.ylabel('previous_price')
plt.show()

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdi_si [['current_price', 'rrp','previous_price']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=['current_price_mmnorm', 'rrp_mmnorm','previous_price_mmnorm']); df_noncat_minmax_norm

#df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdi_si.columns+'_mmnorm'); df_noncat_minmax_norm
df_noncat_mdt_mmn = df_noncat_mdi_si.join(df_noncat_minmax_norm); df_noncat_mdt_mmn # (Missing Data Treated) Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scaler
#df_noncat_mdt_mmn = pd.merge(df_noncat_mdt, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#        current_price     rrp  previous_price  current_price_mmnorm  \
# 0              72.00  100.00       51.095332              0.296045
# 1              17.00   21.00       51.095332              0.061393
# 2              34.00   43.00       51.095332              0.133922
# 3              31.00   42.00       51.095332              0.121123
# 4              23.00   48.00       51.095332              0.086992
# ...              ...     ...             ...                   ...
# 61195          53.69  108.96       66.320000              0.217927
# 61196          47.37   91.59       58.430000              0.190964
# 61197          48.00   78.00       51.095332              0.193652
# 61198          27.00   53.00       51.095332              0.104057
# 61199          31.00   51.00       51.095332              0.121123
#
#        rrp_mmnorm  previous_price_mmnorm
# 0        0.251328               0.280741
# 1        0.033883               0.280741
# ...

# %%
# Pre-Processed Dataset

# Using Scikit Learn Ordinal Encoder : df_cat_mdt_code_oe [Superior]

# Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# Using Scikit Learn Standard Scaler : df_noncat_mdt_std [Standardization]


# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset

# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd


# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
final_df = pd.merge(df_ppd, df[['cluster']], how='left', left_index=True, right_index=True)
print(final_df)
# Out:
#       Gender currency      productType  Gender_code  productType_code  \
# 0          M      USD          Product          1.0               0.0
# 1          M      USD          Product          1.0               0.0
# 2          M      USD          Product          1.0               0.0
# 3          M      USD          Product          1.0               0.0
# 4          M      USD          Product          1.0               0.0
# ...      ...      ...              ...          ...               ...
# 61195      F      USD          Product          0.0               0.0
# 61196      F      USD          Product          0.0               0.0
# 61197      F      USD          Product          0.0               0.0
# 61198      F      USD          Product          0.0               0.0
# 61199      F      USD  MixMatchProduct          0.0               0.0
#
#        currency_code  current_price     rrp  previous_price  \
# 0                2.0          72.00  100.00       51.095332
# ...

# %%
final_new_df=final_df[['Gender_code', 'productType_code','currency_code', 'current_price_mmnorm', 'rrp_mmnorm','previous_price_mmnorm','cluster']]

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib.colors import ListedColormap

# %%
fashion_inputs = final_df[['Gender_code', 'productType_code', 'currency_code', 'current_price_mmnorm', 'rrp_mmnorm', 'previous_price_mmnorm']]
fashion_inputs

fashion_output = final_df[['cluster']]
fashion_output

fashion_inputs_names = fashion_inputs.columns
fashion_inputs_names

fashion_output_labels = fashion_output['cluster'].unique().astype(str)
fashion_output_labels

# Split the fashion Data Subset into Training & Testing Sets
train_fashion_inputs, test_fashion_inputs, train_fashion_output, test_fashion_output = train_test_split(fashion_inputs, fashion_output, test_size=0.25, random_state=1234)

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45058)

# Perform the stratified split to get training and testing indices
for train_index, test_index in stratified_split.split(fashion_inputs, fashion_output):
    fashion_inputs_train, fashion_inputs_test = fashion_inputs.iloc[train_index], fashion_inputs.iloc[test_index]
    fashion_output_train, fashion_output_test = fashion_output.iloc[train_index], fashion_output.iloc[test_index]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import numpy as np

# Initialize Logistic Regression model with L1 regularization
logreg_l1 = LogisticRegression(penalty='l1', solver='liblinear', random_state=45058)

# Fit the model on the training data
logreg_l1.fit(fashion_inputs_train, fashion_output_train.values.ravel())

# Get feature importances from the fitted model
feature_importances = np.abs(logreg_l1.coef_).flatten()

# Calculate the threshold as 20% of the maximum feature importance
threshold = 0.2 * np.max(feature_importances)

# Create a selector object to select features based on non-zero coefficients
selector = SelectFromModel(logreg_l1, threshold=threshold)

# Transform the training and testing input data to select features
fashion_inputs_train_selected = selector.transform(fashion_inputs_train)
fashion_inputs_test_selected = selector.transform(fashion_inputs_test)

# Get the selected features
selected_features = fashion_inputs_names[selector.get_support()]

# Print the selected features and the calculated threshold
print("Selected Features:", selected_features)
print("Threshold:", threshold)
# Out:
# Selected Features: Index(['current_price_mmnorm', 'rrp_mmnorm', 'previous_price_mmnorm'], dtype='object')
# Threshold: 35.38380584271615
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45058, max_depth=3)  # Other Criteria : Entropy, Log Loss
dtc_model = dtc.fit(fashion_inputs_train, fashion_output_train)  # Train the decision tree model
dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45058)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(fashion_inputs_names))  # Export rules using the decision tree model
print(dtc_model_rules)
# Out:
# |--- current_price_mmnorm <= 0.20
# |   |--- previous_price_mmnorm <= 0.31
# |   |   |--- rrp_mmnorm <= 0.24
# |   |   |   |--- class: 1
# |   |   |--- rrp_mmnorm >  0.24
# |   |   |   |--- class: 0
# |   |--- previous_price_mmnorm >  0.31
# |   |   |--- Gender_code <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- Gender_code >  0.50
# |   |   |   |--- class: 1
# |--- current_price_mmnorm >  0.20
# |   |--- rrp_mmnorm <= 0.49
# |   |   |--- rrp_mmnorm <= 0.21
# |   |   |   |--- class: 1
# |   |   |--- rrp_mmnorm >  0.21
# |   |   |   |--- class: 0
# |   |--- rrp_mmnorm >  0.49
# |   |   |--- class: 2

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': fashion_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 3)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#                  feature  importance
# 3   current_price_mmnorm       0.587
# 4             rrp_mmnorm       0.307
# 5  previous_price_mmnorm       0.091
# 0            Gender_code       0.014
# 1       productType_code       0.000
# 2          currency_code       0.000

# %%
# Decision Tree : Model Prediction (Training Subset)
dtc_model_predict = dtc_model.predict(fashion_inputs_train); dtc_model_predict
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
 #Decision Tree : Prediction (Testing Subset)
dtc_predict = dtc_model.predict(fashion_inputs_test); dtc_predict
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
# Decision Tree : Model Evaluation (Training Subset)
dtc_model_conf_mat = pd.DataFrame(confusion_matrix(fashion_output_train, dtc_model_predict)); dtc_model_conf_mat
dtc_model_perf = classification_report(fashion_output_train, dtc_model_predict); print(dtc_model_perf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     14462
#            1       1.00      1.00      1.00     30909
#            2       1.00      1.00      1.00      3589
#
#     accuracy                           1.00     48960
#    macro avg       1.00      1.00      1.00     48960
# weighted avg       1.00      1.00      1.00     48960

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Set a larger figure size for better clarity
plt.figure(figsize=(10, 10))

# Plot the decision tree
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=fashion_inputs_names, class_names=fashion_output_labels, rounded=True, filled=True, fontsize=20)

# Show the plot
plt.show()

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_model_conf_mat, annot=True, fmt='d', cmap='Paired')

# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, cross_val_score
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
import numpy as np
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Your code for data preprocessing and model training goes here...
# Replace placeholder comments with actual preprocessing and model training code

# End time
end_time = time.time()

# Time taken
execution_time = end_time - start_time

# Memory usage
memory_used = memory_usage()

# Print memory usage and execution time
print("Memory used (MB):", memory_used)
print("Time taken (seconds):", execution_time)

# Make predictions using the trained model and measure accuracy
# Assuming you have already trained your decision tree model (dtc_model) and logistic regression model (logreg_l1)
# For example:

# Decision Tree predictions and evaluation
dtc_predict_train = dtc_model.predict(fashion_inputs_train)
dtc_predict_test = dtc_model.predict(fashion_inputs_test)

# Calculate accuracy for decision tree
accuracy_dtc_train = accuracy_score(fashion_output_train, dtc_predict_train)
accuracy_dtc_test = accuracy_score(fashion_output_test, dtc_predict_test)

# Print accuracy
print("Decision Tree Training Accuracy:", accuracy_dtc_train)
print("Decision Tree Testing Accuracy:", accuracy_dtc_test)
# Out:
# Memory used (MB): 343.61328125
# Time taken (seconds): 4.124641418457031e-05
# Decision Tree Training Accuracy: 1.0
# Decision Tree Testing Accuracy: 1.0

# %% [markdown]
# # ***KNN***

# %%
# Specify the number of neighbors (k)
k = 5

# Initialize KNN classifier with k neighbors
knn = KNeighborsClassifier(n_neighbors=k)

# Fit the KNN model using the training data
knn.fit(fashion_inputs_train, fashion_output_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
# Make predictions using the testing data
y_pred = knn.predict(fashion_inputs_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(fashion_output_test, y_pred)
print(f'Accuracy: {accuracy}')

# Generate classification report
classification_rep = classification_report(fashion_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(fashion_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3616
#            1       1.00      1.00      1.00      7727
#            2       1.00      1.00      1.00       897
#
#     accuracy                           1.00     12240
#    macro avg       1.00      1.00      1.00     12240
# weighted avg       1.00      1.00      1.00     12240
#
# Confusion Matrix:
# [[3616    0    0]
#  [   0 7727    0]
#  [   0    0  897]]

# %%
k_values = [9, 11, 13, 15, 17]
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(fashion_inputs_train, fashion_output_train)  # Use your training data here
    y_pred = knn.predict(fashion_inputs_test)  # Use your testing data here
    accuracy = accuracy_score(fashion_output_test, y_pred)  # Compare predictions with true labels
    print(f'Accuracy for k={k}: {accuracy}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=9: 1.0
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=11: 1.0
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=13: 1.0
# ...

# %%
# Plot confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# Assuming df1_output_test and y_pred are the true and predicted labels, respectively
plot_confusion_matrix(fashion_output_test, y_pred)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Specify the number of neighbors (k)
k_values = [9, 11, 13, 15, 17]

for k in k_values:
    # Initialize KNN classifier with k neighbors
    knn = KNeighborsClassifier(n_neighbors=k)

    # Start time
    start_time = time.time()

    # Fit the KNN model using the training data
    knn.fit(fashion_inputs_train, fashion_output_train)

    # End time
    end_time = time.time()

    # Time taken for training
    training_time = end_time - start_time

    # Make predictions using the testing data
    y_pred = knn.predict(fashion_inputs_test)

    # Calculate accuracy
    accuracy = accuracy_score(fashion_output_test, y_pred)

    # Generate classification report
    classification_rep = classification_report(fashion_output_test, y_pred)

    # Generate confusion matrix
    conf_mat = confusion_matrix(fashion_output_test, y_pred)

    # Memory usage
    memory_used = memory_usage()

    print(f'\nResults for k={k}:')
    print(f'Training Time (seconds): {training_time}')
    print(f'Accuracy: {accuracy}')
    print(f'Classification Report:\n{classification_rep}')
    print(f'Confusion Matrix:\n{conf_mat}')
    print(f'Memory Used (MB): {memory_used}')

# Plot confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# Assuming fashion_output_test and y_pred are the true and predicted labels, respectively
plot_confusion_matrix(fashion_output_test, y_pred)

from sklearn.model_selection import cross_val_score

# Define the KNN classifier with a chosen number of neighbors (k)
knn = KNeighborsClassifier(n_neighbors=13)  # Example value, you can adjust this

# Perform cross-validation with 20 folds
cv_scores = cross_val_score(knn, fashion_inputs, fashion_output.values.ravel(), cv=20)

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)

# Calculate and print the average accuracy
avg_accuracy = cv_scores.mean()
print("Average Accuracy:", avg_accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=9:
# Training Time (seconds): 0.10313177108764648
# Accuracy: 1.0
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3616
#            1       1.00      1.00      1.00      7727
#            2       1.00      1.00      1.00       897
#
#     accuracy                           1.00     12240
#    macro avg       1.00      1.00      1.00     12240
# weighted avg       1.00      1.00      1.00     12240
#
# Confusion Matrix:
# [[3616    0    0]
#  [   0 7727    0]
#  [   0    0  897]]
# Memory Used (MB): 346.4296875
# ...

# %% [markdown]
# # # **Logistic Regression**

# %%
# Create and fit a Logistic Regression model
logreg = LogisticRegression(random_state=45058, solver='liblinear')
logreg.fit(fashion_inputs_train, fashion_output_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(random_state=45058, solver='liblinear')

# %%
# Make predictions using the trained model
y_pred = logreg.predict(fashion_inputs_test)

# Calculate accuracy
accuracy = accuracy_score(fashion_output_test, y_pred)
print(f'Accuracy: {accuracy}')

# Generate classification report
classification_rep = classification_report(fashion_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(fashion_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# Accuracy: 0.9706699346405229
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95      3616
#            1       0.96      1.00      0.98      7727
#            2       1.00      1.00      1.00       897
#
#     accuracy                           0.97     12240
#    macro avg       0.99      0.97      0.98     12240
# weighted avg       0.97      0.97      0.97     12240
#
# Confusion Matrix:
# [[3257  359    0]
#  [   0 7727    0]
#  [   0    0  897]]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Create and fit a Logistic Regression model
logreg = LogisticRegression(random_state=45007, solver='liblinear')
logreg.fit(fashion_inputs_train, fashion_output_train)

# End time
end_time = time.time()

# Time taken for training
training_time = end_time - start_time

# Make predictions using the trained model
start_time = time.time()  # Start time for prediction
y_pred = logreg.predict(fashion_inputs_test)
end_time = time.time()  # End time for prediction

# Time taken for prediction
prediction_time = end_time - start_time

# Calculate accuracy
accuracy = accuracy_score(fashion_output_test, y_pred)

# Memory usage
memory_used = memory_usage()

# Print results
print("Time taken for training (seconds):", training_time)
print("Time taken for prediction (seconds):", prediction_time)
print("Accuracy:", accuracy)
print("Memory used (MB):", memory_used)

# Generate classification report
classification_rep = classification_report(fashion_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(fashion_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Time taken for training (seconds): 0.5258808135986328
# Time taken for prediction (seconds): 0.0029854774475097656
# Accuracy: 0.9706699346405229
# Memory used (MB): 347.203125
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95      3616
#            1       0.96      1.00      0.98      7727
#            2       1.00      1.00      1.00       897
#
#     accuracy                           0.97     12240
#    macro avg       0.99      0.97      0.98     12240
# weighted avg       0.97      0.97      0.97     12240
#
# Confusion Matrix:
# [[3257  359    0]
#  [   0 7727    0]
#  [   0    0  897]]

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Create and fit an SVM classifier with RBF kernel
svm_classifier = SVC(kernel='rbf', random_state=45058)
svm_classifier.fit(fashion_inputs_train, fashion_output_train)

# End time
end_time = time.time()

# Time taken for training
training_time = end_time - start_time

# Make predictions using the trained model
start_time = time.time()  # Start time for prediction
y_pred = svm_classifier.predict(fashion_inputs_test)
end_time = time.time()  # End time for prediction

# Time taken for prediction
prediction_time = end_time - start_time

# Calculate accuracy
accuracy = accuracy_score(fashion_output_test, y_pred)

# Memory usage
memory_used = memory_usage()

# Print results
print("Time taken for training (seconds):", training_time)
print("Time taken for prediction (seconds):", prediction_time)
print("Accuracy:", accuracy)
print("Memory used (MB):", memory_used)

# Generate classification report
classification_rep = classification_report(fashion_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(fashion_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Time taken for training (seconds): 10.700165748596191
# Time taken for prediction (seconds): 3.730808973312378
# Accuracy: 1.0
# Memory used (MB): 343.62109375
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3616
#            1       1.00      1.00      1.00      7727
#            2       1.00      1.00      1.00       897
#
#     accuracy                           1.00     12240
#    macro avg       1.00      1.00      1.00     12240
# weighted avg       1.00      1.00      1.00     12240
#
# Confusion Matrix:
# [[3616    0    0]
#  [   0 7727    0]
#  [   0    0  897]]

# %%
import pandas as pd
import time
import psutil
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Data preprocessing and splitting
# Assuming you have your data loaded into fashion_inputs and fashion_output
fashion_inputs_train, fashion_inputs_test, fashion_output_train, fashion_output_test = train_test_split(fashion_inputs, fashion_output, test_size=0.2, random_state=42)

# Results storage
results = []

# Decision Tree
dt_start_time = time.time()
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(fashion_inputs_train, fashion_output_train)
dt_training_time = time.time() - dt_start_time
dt_memory_used = memory_usage()
dt_pred = dt_model.predict(fashion_inputs_test)
dt_accuracy = accuracy_score(fashion_output_test, dt_pred)
results.append({'Model': 'Decision Tree', 'Time Taken (s)': dt_training_time, 'Memory Used (MB)': dt_memory_used, 'Accuracy': dt_accuracy})

# KNN
k_values = [5, 7, 9, 11, 13, 15]
for k in k_values:
    knn_start_time = time.time()
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(fashion_inputs_train, fashion_output_train)
    knn_training_time = time.time() - knn_start_time
    knn_memory_used = memory_usage()
    knn_pred = knn.predict(fashion_inputs_test)
    knn_accuracy = accuracy_score(fashion_output_test, knn_pred)
    results.append({'Model': f'KNN (k={k})', 'Time Taken (s)': knn_training_time, 'Memory Used (MB)': knn_memory_used, 'Accuracy': knn_accuracy})

# Logistic Regression
lr_start_time = time.time()
logreg = LogisticRegression(random_state=45058, solver='liblinear')
logreg.fit(fashion_inputs_train, fashion_output_train)
lr_training_time = time.time() - lr_start_time
lr_memory_used = memory_usage()
lr_pred = logreg.predict(fashion_inputs_test)
lr_accuracy = accuracy_score(fashion_output_test, lr_pred)
results.append({'Model': 'Logistic Regression', 'Time Taken (s)': lr_training_time, 'Memory Used (MB)': lr_memory_used, 'Accuracy': lr_accuracy})

# SVM
svm_start_time = time.time()
svm_classifier = SVC(kernel='rbf', random_state=45058)
svm_classifier.fit(fashion_inputs_train, fashion_output_train)
svm_training_time = time.time() - svm_start_time
svm_memory_used = memory_usage()
svm_pred = svm_classifier.predict(fashion_inputs_test)
svm_accuracy = accuracy_score(fashion_output_test, svm_pred)
results.append({'Model': 'SVM', 'Time Taken (s)': svm_training_time, 'Memory Used (MB)': svm_memory_used, 'Accuracy': svm_accuracy})

# Create DataFrame
results_df = pd.DataFrame(results)

# Display the results
print(results_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...
